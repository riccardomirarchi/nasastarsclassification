# %%
import pandas as pd
import altair as alt

# %%
dataset = pd.read_csv("Stars_manipulated.csv")

# %%
def normalize_colums(column):
    dataset[column] = (dataset[column] - dataset[column].min()) / (dataset[column].max() - dataset[column].min())
    
numerical_columns = ['Temperature', 'L', 'R', 'A_M']

for column in numerical_columns:
    normalize_colums(column)

# %%
data = dataset[dataset['Spectral_Class'] == 'O']

dom = ['Red Dwarf', 'Brown Dwarf', 'White Dwarf', 'Main Sequence', 'Super Giants', 'Hyper Giants']
rng = ['#fc0000', '#874701', '#029c49', '#0055ff', '#00d5ff', '#d400ff']

alt.Chart(data, title = "Classe spettrale O").mark_point().encode( 
    
    x = alt.X('Temperature',
         scale = alt.Scale(domain = (min(dataset.Temperature), max(dataset.Temperature))),
         axis = alt.Axis(format='K', title='Color Temperature', grid = False)
         ),
    
    y = alt.Y('L',
         scale = alt.Scale(domain = (min(dataset.L), max(dataset.L))),
         axis = alt.Axis(format='K', title='Brightness (L)', grid = False)
         ),
    
    size = alt.Size('R', 
                    scale = alt.Scale(domain = [0, 1]), 
                    legend = alt.Legend(title = 'Dimension (R)')
                   ),
    
    color = alt.Color('Type', scale=alt.Scale(domain=dom, range=rng)
                     )
    
)
# Out:
# alt.Chart(...)

# %%
data = dataset[dataset['Spectral_Class'] == 'B']

alt.Chart(data, title = "Classe spettrale B").mark_point().encode( 
    
    x = alt.X('Temperature',
         scale = alt.Scale(domain = (min(dataset.Temperature), max(dataset.Temperature))),
         axis = alt.Axis(format='K', title='Color Temperature', grid = False)
         ),
    
    y = alt.Y('L',
         scale = alt.Scale(domain = (min(dataset.L), max(dataset.L))),
         axis = alt.Axis(format='K', title='Brightness (L)', grid = False)
         ),
    
    size = alt.Size('R', 
                    scale = alt.Scale(domain = [0, 1]), 
                    legend = alt.Legend(title = 'Dimension (R)')
                   ),
    
    color = alt.Color('Type', scale=alt.Scale(domain=dom, range=rng)
                     )
    
)
# Out:
# alt.Chart(...)

# %%
data = dataset[dataset['Spectral_Class'] == 'A']

alt.Chart(data, title = "Classe spettrale A").mark_point().encode( 
    
    x = alt.X('Temperature',
         scale = alt.Scale(domain = (min(dataset.Temperature), max(dataset.Temperature))),
         axis = alt.Axis(format='K', title='Color Temperature', grid = False)
         ),
    
    y = alt.Y('L',
         scale = alt.Scale(domain = (min(dataset.L), max(dataset.L))),
         axis = alt.Axis(format='K', title='Brightness (L)', grid = False)
         ),
    
    size = alt.Size('R', 
                    scale = alt.Scale(domain = [0, 1]), 
                    legend = alt.Legend(title = 'Dimension (R)')
                   ),
    
    color = alt.Color('Type', scale=alt.Scale(domain=dom, range=rng)
                     )
    
)
# Out:
# alt.Chart(...)

# %%
data = dataset[dataset['Spectral_Class'] == 'F']

alt.Chart(data, title = "Classe spettrale F").mark_point().encode( 
    
    x = alt.X('Temperature',
         scale = alt.Scale(domain = (min(dataset.Temperature), max(dataset.Temperature))),
         axis = alt.Axis(format='K', title='Color Temperature', grid = False)
         ),
    
    y = alt.Y('L',
         scale = alt.Scale(domain = (min(dataset.L), max(dataset.L))),
         axis = alt.Axis(format='K', title='Brightness (L)', grid = False)
         ),
    
    size = alt.Size('R', 
                    scale = alt.Scale(domain = [0, 1]), 
                    legend = alt.Legend(title = 'Dimension (R)')
                   ),
    
    color = alt.Color('Type', scale=alt.Scale(domain=dom, range=rng)
                     )
    
)
# Out:
# alt.Chart(...)

# %%
data = dataset[dataset['Spectral_Class'] == 'G']

alt.Chart(data, title = "Classe spettrale G").mark_point().encode( 
    
    x = alt.X('Temperature',
         scale = alt.Scale(domain = (min(dataset.Temperature), max(dataset.Temperature))),
         axis = alt.Axis(format='K', title='Color Temperature', grid = False)
         ),
    
    y = alt.Y('L',
         scale = alt.Scale(domain = (min(dataset.L), max(dataset.L))),
         axis = alt.Axis(format='K', title='Brightness (L)', grid = False)
         ),
    
    size = alt.Size('R', 
                    scale = alt.Scale(domain = [0, 1]), 
                    legend = alt.Legend(title = 'Dimension (R)')
                   ),
    
    color = alt.Color('Type', scale=alt.Scale(domain=dom, range=rng)
                     )
    
)
# Out:
# alt.Chart(...)

# %%
data = dataset[dataset['Spectral_Class'] == 'K']

alt.Chart(data, title = "Classe spettrale K").mark_point().encode( 
    
    x = alt.X('Temperature',
         scale = alt.Scale(domain = (min(dataset.Temperature), max(dataset.Temperature))),
         axis = alt.Axis(format='K', title='Color Temperature', grid = False)
         ),
    
    y = alt.Y('L',
         scale = alt.Scale(domain = (min(dataset.L), max(dataset.L))),
         axis = alt.Axis(format='K', title='Brightness (L)', grid = False)
         ),
    
    size = alt.Size('R', 
                    scale = alt.Scale(domain = [0, 1]), 
                    legend = alt.Legend(title = 'Dimension (R)')
                   ),
    
    color = alt.Color('Type', scale=alt.Scale(domain=dom, range=rng)
                     )
    
)
# Out:
# alt.Chart(...)

# %%
data = dataset[dataset['Spectral_Class'] == 'M']

alt.Chart(data, title = "Classe spettrale M").mark_point().encode( 
    
    x = alt.X('Temperature',
         scale = alt.Scale(domain = (min(dataset.Temperature), max(dataset.Temperature))),
         axis = alt.Axis(format='K', title='Color Temperature', grid = False)
         ),
    
    y = alt.Y('L',
         scale = alt.Scale(domain = (min(dataset.L), max(dataset.L))),
         axis = alt.Axis(format='K', title='Brightness (L)', grid = False)
         ),
    
    size = alt.Size('R', 
                    scale = alt.Scale(domain = [0, 1]), 
                    legend = alt.Legend(title = 'Dimension (R)')
                   ),
    
    color = alt.Color('Type', scale=alt.Scale(domain=dom, range=rng)
                     )
    
)
# Out:
# alt.Chart(...)
